# %%
print("codigo por partesss")
# Out:
# codigo por partesss

# %%
import pandas as pd

# %%
precios = pd.Series([12000, 8500, 34000, 5200, 19900])
print(precios)
# Out:
# 0    12000
# 1     8500
# 2    34000
# 3     5200
# 4    19900
# dtype: int64

# %%
precios_con_iva = precios * 1.19
print(precios_con_iva)
# Out:
# 0    14280.0
# 1    10115.0
# 2    40460.0
# 3     6188.0
# 4    23681.0
# dtype: float64

# %%
ventas = pd.DataFrame([
    {"producto": "Notebook",  "categoria": "tech",    "precio": 320000},
    {"producto": "Mouse",     "categoria": "tech",    "precio": 8500},
    {"producto": "Escritorio","categoria": "muebles", "precio": 85000},
    {"producto": "Silla",     "categoria": "muebles", "precio": 45000},
])

print(ventas)
# Out:
#      producto categoria  precio
# 0    Notebook      tech  320000
# 1       Mouse      tech    8500
# 2  Escritorio   muebles   85000
# 3       Silla   muebles   45000

# %%
print(ventas.shape)       # (4, 3) -> 4 filas, 3 columnas
print(ventas.columns)     # Index(['producto', 'categoria', 'precio'], dtype='object')
print(ventas.dtypes)      # tipo de dato de cada columna
print(ventas.head(2))     # las primeras 2 filas
# Out:
# (4, 3)
# Index(['producto', 'categoria', 'precio'], dtype='object')
# producto     object
# categoria    object
# precio        int64
# dtype: object
#    producto categoria  precio
# 0  Notebook      tech  320000
# 1     Mouse      tech    8500

# %%
print(ventas[["producto", "precio"]])
#Observa el doble corchete: el corchete de afuera es la selección,
#el de adentro es la lista de nombres de columnas que quieres. Si te olvidas uno de los corchetes, Pandas no va a entender qué le estás pidiendo.
# Out:
#      producto  precio
# 0    Notebook  320000
# 1       Mouse    8500
# 2  Escritorio   85000
# 3       Silla   45000

# %%
#Para seleccionar filas por posición, usas .iloc[] (de "index location"):

print(ventas.iloc[0])      # la primera fila
print(ventas.iloc[0:3])    # las primeras tres filas
# Out:
# producto     Notebook
# categoria        tech
# precio         320000
# Name: 0, dtype: object
#      producto categoria  precio
# 0    Notebook      tech  320000
# 1       Mouse      tech    8500
# 2  Escritorio   muebles   85000
