# %%
saludo = "hola"
numero = 30
numero2 = 20
nombre_apellido = "maria gomez"
#snake_case
decimal = 30.5
activo = True
desconectado = False
vacio = None


nombres = ["maria","pablo"]

usuario = {"nombre": "mariaaaaaa",
           "apellido":"gomez"
}

# %%
print(saludo)
# Out:
# hola

# %%
#diccionario: 

print(usuario)
# Out:
# {'nombre': 'maria', 'apellido': 'gomez'}

# %%
print(usuario ["nombre"])
# Out:
# maria

# %%
 print(type(nombres))
# Out:
# <class 'list'>

# %%
print(type(activo))
# Out:
# <class 'bool'>

# %%
#en listas, hay induce, ubicacion, largo

print(nombres[1])
# Out:
# pablo

# %%
#operaciones aritmeticas

resultado = numero + numero2
print(resultado)
# Out:
# 50

# %%
#concatenar:
print(saludo+""+nombre_apellido)
# Out:
# holamaria gomez

# %%
#forma mas pro de cncatenar


print(f"{saludo}{nombre_apellido}")
# Out:
# holamaria gomez

# %%
print(f"{saludo}{usuario["nombre"]}")
# Out:
# holamaria

# %%
'''conversion entre tipos de datos (casting)  si es "20" y queremos pasarlo a 20 numerico se le pone la funcion int(variable)
operadores : mayor, menor, igual a , etc

aritmeticos
relacionales/comparacion es igual? ==  , es distinto de? !=,es mayor a ?<,>, 
logicos and, or , not
'''
# Out:
# 'conversion entre tipos de datos (casting)  si es "20" y queremos pasarlo a 20 numerico se le pone la funcion int(variable)\noperadores : mayor, menor, igual a , etc\n\naritmeticos\nrelacionales/comparacion  ==  , distinto de !=,<,>, \nlogicos and, or , not\n'

# %%
print(numero == (decimal))
# Out:
# False

# %%
if usuario["nombre"] == "maria":
    print(f"Hola {usuario["nombre"]}")
elif usuario ["nombre"] == "pablo":
     print(f"Hola{usuario[nombre]}")
else : 
    print(f"debes crear una cuenta")
# Out:
# debes crear una cuenta
